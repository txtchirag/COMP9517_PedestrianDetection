# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def generate_histogram(img):
    #caluclate histogram using numpy
    hist,bins = np.histogram(img.flatten(),256,[0,256])
    #cumulative distribution function calculation
    cdf = hist.cumsum()
    #plotting the pixel distribution 
    plt.plot(cdf_normalized, color = 'b')
    plt.hist(img.flatten(),256,[0,256], color = 'r')
    plt.xlim([0,256])
    plt.legend(('cdf','histogram'), loc = 'upper left')
    plt.show()
    return hist

# %%
#Normalising image using histogram equalization
def normalize_grayimage(image):
    image = cv2.equalizeHist(image)
    cv2.imshow("Equalized img", image)
    return image

# %%
#Read the frames in from sequence
frame1 = cv2.imread('sequence/000726.jpg')
frame2 = cv2.imread('sequence/000727.jpg')

# %%
#frame difference
img = cv2.absdiff(frame1,frame2)

# %%
# cascPath = "haarcascade_pedestrian.xml"
# pplCascade = cv2.CascadeClassifier(cascPath)
# #image = cv2.imread(imagePath)
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# gray = normalize_grayimage(gray)
 
# pedestrians = pplCascade.detectMultiScale(gray,scaleFactor=1.2,minNeighbors=10,minSize=(32,96),flags = cv2.cv.CV_HAAR_SCALE_IMAGE)

# for (x, y, w, h) in pedestrians:
#     cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
#Using pedestrian.xml as cascade classifier
cascade = cv2.CascadeClassifier('pedestrian.xml')
#convert to grayscale
gray = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
#detect the pedestrians using detect Multiscale
person = cascade.detectMultiScale(gray,1.3,2)
for(a,b,c,d) in person:
    cv2.rectangle(frame1,(a,b),(a+c,b+d),(0,255,210),4)

# %%
plt.imshow(frame1)
#recognises only one pedestrian in frame

# %%
#difference of frames visualised
plt.imshow(img)
